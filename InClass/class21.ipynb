# %% [markdown]
# ## 1.

# %% [markdown]
# It finally worked

# %% [markdown]
# <img width="861" alt="Screen Shot 2021-07-24 at 3 03 44 PM" src="https://user-images.githubusercontent.com/79989694/126880211-b2a04b38-68ce-45b2-8808-d20f25d94017.png">

# %% [markdown]
# <img width="1440" alt="Screen Shot 2021-07-24 at 3 05 42 PM" src="https://user-images.githubusercontent.com/79989694/126880219-5879d24e-58e7-42bb-a642-19f98e0351ec.png">

# %% [markdown]
# ## 2.

# %%
from flask import Flask, json, render_template, request
import os
import pandas as pd

# %%
app = Flask(__name__)

# %%
json_url = os.path.join(app.static_folder,"","us_gdp.json")
data_json = json.load(open(json_url))

# %%
new = data_json[1]
pd.DataFrame(new)
# Out:
#                                             indicator  \
# 0   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 1   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 4   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# ..                                                ...
# 56  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 57  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 58  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 59  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 60  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                    country countryiso3code  date  \
# 0   {'id': 'US', 'value': 'United States'}             USA  2020
# 1   {'id': 'US', 'value': 'United States'}             USA  2019
# 2   {'id': 'US', 'value': 'United States'}             USA  2018
# ...
